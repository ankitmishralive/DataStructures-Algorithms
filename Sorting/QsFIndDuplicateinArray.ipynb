# %% [markdown]
# # Find Duplicate in Array

# %% [markdown]
# Array Question hai tou 2 pointer approach ya sorting approach se complexity kam krni hai

# %% [markdown]
# Sort karenge then
# duplicate number jo hoga consequtive present hoga  then

# %% [markdown]
# 1 3 2 4 2
#
# after sorting
#
# 1 2 2 3 4
#
# for i in range (1,n):
#    if arr[i-1]== arr[i]
#    return arr[i]
#
#
#
# THis wil just take 0(n)

# %%
def findDuplicate(array):
    array.sort()
    for i in range(1,len(array)):
        if array[i-1]==array[i]:
            return array[i]
    return "No Duplicate Found"

# %%
data = [1,3,2,9,0,2]
# print(len(data))
print(findDuplicate(data))
# print(data)
# Out:
# 2

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Find Duplicate in Array
#
# 10 Comapnies including Amazon

# %%
def findDuplicate(arr:list, n:int):
    # Write your code here.
    # Returns an integer.
    arr.sort()
    for i in range(1,n):
        if arr[i-1] == arr[i]:
            return arr[i]
    return "No found duplicate"

# %% [markdown]
# ### Find Duplicates In Array

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### it looks goood so  most likely all this as per plan, after sem
